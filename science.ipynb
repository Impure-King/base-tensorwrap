# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.arange(1, 8)
y = np.array([23.6, 28.5, 28.5, 29.5, 28.4, 25, 23.7])

# %%
x1 = np.arange(1, 8, 0.001)

# %%
plt.scatter(x, y)
plt.plot(x1, w1 * x1 ** 3 + w2 * x1**2 + b1 * x1 + b2)
plt.show()

# %%
w1, w2, b1, b2 = np.polyfit(x, y, deg=3)
